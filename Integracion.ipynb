# %% [markdown]
# # Integración

# %% [markdown]
# En esta etapa importamos el resultado de las otras transformaciones siendo INUMET_INE_promedio.csv, UTE_INE_promedio, y ECH_promedio. Una vez cargados procedemos a ejecutar dos joins, primero UTE_INE_promedio con ECH_promedio y luego al resultado de este join se le ejecuta otro join con INUMET_INE_promedio. Finalmente se materializa dicha integracion en el archivo "Integracion.csv".

# %%
import pandas as pd


InumetDF = pd.read_csv('INUMET/INUMET_INE.csv').rename({'seccion':'secc', 'segmento':'segm', 'Año':'anio', 'Mes':'mes'}, axis=1)

UteDF = pd.read_csv('UTE/UTE_INE_promedio.csv')

EchDF = pd.read_csv('ECH/ECH_promedio.csv')

UteAndECH = UteDF.merge(EchDF, how='left', on=['segm','secc', 'anio'])

UteAndECHAndInumet = UteAndECH.merge(InumetDF, how='left', on=['anio', 'mes', 'secc', 'segm'])

UteAndECHAndInumet.to_csv('Integracion.csv',index=False)

# %% [markdown]
# Visualización del resultado como dataframe de la integración.

# %%
UteAndECHAndInumet
# Out:
#        secc   segm    anio   mes  cantidadPredios  tarifa-%TRS  tarifa-%TCB  \
# 0       1.0    1.0  2017.0   1.0            234.0     0.696581     0.205128
# 1       1.0    1.0  2017.0   2.0            243.0     0.683128     0.205761
# 2       1.0    1.0  2017.0   3.0            257.0     0.697674     0.201550
# 3       1.0    1.0  2017.0   4.0            236.0     0.690678     0.207627
# 4       1.0    1.0  2017.0   5.0            265.0     0.690566     0.211321
# ...     ...    ...     ...   ...              ...          ...          ...
# 30599  99.0  267.0  2019.0   8.0            233.0     0.751073     0.175966
# 30600  99.0  267.0  2019.0   9.0            233.0     0.751073     0.171674
# 30601  99.0  267.0  2019.0  10.0            231.0     0.748918     0.173160
# 30602  99.0  267.0  2019.0  11.0            229.0     0.742358     0.179039
# 30603  99.0  267.0  2019.0  12.0            229.0     0.742358     0.179039
#
#        tarifa-%TRD  energia_facturada  pesoano  ...  cant_televisores_prom  \
# 0         0.034188            43268.0    581.0  ...               0.731497
# 1         0.037037            43191.0    581.0  ...               0.731497
# 2         0.034884            48271.0    581.0  ...               0.731497
# 3         0.033898            43156.0    581.0  ...               0.731497
# 4         0.037736            49264.0    581.0  ...               0.731497
# ...            ...                ...      ...  ...                    ...
# 30599     0.034335            63414.3    359.0  ...               0.571031
# 30600     0.034335            61717.7    359.0  ...               0.571031
# 30601     0.034632            53436.0    359.0  ...               0.571031
# 30602     0.034934            55605.7    359.0  ...               0.571031
# 30603     0.034934            47770.4    359.0  ...               0.571031
#
#        ingresos_hogar_prom  cant_ac_prom  porcentaje_calefaccio_electrica  \
# 0             49045.873494      0.616179                             0.50
# 1             49045.873494      0.616179                             0.50
# 2             49045.873494      0.616179                             0.50
# 3             49045.873494      0.616179                             0.50
# 4             49045.873494      0.616179                             0.50
# ...                    ...           ...                              ...
# 30599         55746.501393      0.114206                             0.23
# 30600         55746.501393      0.114206                             0.23
# 30601         55746.501393      0.114206                             0.23
# 30602         55746.501393      0.114206                             0.23
# 30603         55746.501393      0.114206                             0.23
#
#        TMaxPromedio  TMinPromedio  TMaxRegistrada  TMinRegistrada  \
# 0              28.9          19.1            35.1            14.4
# 1              28.7          20.7            33.9            14.3
# 2              25.5          17.4            34.5            11.1
# 3              22.8          14.8            28.2             9.5
# 4              19.1          12.0            27.9             6.2
# ...             ...           ...             ...             ...
# 30599          15.0           7.4            26.0             1.2
# 30600          17.2           7.9            27.2             2.8
# 30601          18.9          11.9            29.0             3.6
# 30602          24.9          15.6            33.6            11.2
# 30603          26.3          16.4            34.9            10.4
#
#        TMaxDesviacion  TMinDesviacion
# 0                 3.4             2.3
# 1                 3.3             2.3
# 2                 3.0             3.1
# 3                 3.1             3.0
# 4                 4.0             3.1
# ...               ...             ...
# 30599             4.6             3.1
# 30600             5.1             3.0
# 30601             4.6             3.4
# 30602             3.7             2.1
# 30603             4.6             3.5
#
# [30604 rows x 27 columns]
